# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pickle
import pandas as pd
import healpy as hp
import pysm3.units as u
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.cm as cm
from astropy.table import Table
import multiprocessing
from time import time
import utils 
import os
os.environ[
    "OMP_NUM_THREADS"
] = "64"
#np.random.seed(10)

# %% [markdown]
# # Read Map

# %%
comp = "IQU"
mdir = "/global/project/projectdirs/cmb/data/planck2018/pr3/frequencymaps/"
m, h = hp.read_map(mdir + "HFI_SkyMap_353_2048_R3.01_full.fits",
                                       [c + "_STOKES" for c in comp], dtype = np.float64, h = True)
m <<= u.K_CMB
m = m.to('uK_RJ', equivalencies = u.cmb_equivalencies(353 * u.GHz))
I,Q,U = m
P = Q**2 + U**2
I = I**2

# %% [markdown]
# # Read Catalogue

# %%
target_url = 'https://irsa.ipac.caltech.edu/data/Planck/release_2/catalogs/HFI_PCCS_GCC_R2.02.fits'
PGCC = Table.read(target_url, format = 'fits')
df = PGCC.to_pandas()
df = df[df.FLUX_QUALITY == 1]    # Cut to best quality sources
df = df[df.FLUX_BLENDING == 0]   # Cut out overlapping sources
df = df.reset_index(drop = True) # Reset dataframe indices

# %% [markdown]
# # Cut out cold clump patches
#
# Stack full catalogue in $I^2$ and $P^2$.
#
# Select destination folder for pickled map-cutouts if you choose to save all patches

# %%
output_dir = "/global/cscratch1/sd/justinc/"

# %%
def stack_I(l, b, p):
    return(hp.gnomview(I, rot = [l,b,p],
                      reso = 1, xsize = 50,
                      coord = 'G', no_plot = True,
                      return_projected_map = True))
def stack_P(l, b, p):
    return(hp.gnomview(P, rot = [l,b,p],
                      reso = 1, xsize = 50,
                      coord = 'G', no_plot = True,
                      return_projected_map = True))

def repeatI(l,b):
    p = np.random.randint(0,360,5)
    res = []
    for i in range(len(p)):
        print(p[i])
        res.append(stack_I(l,b,p[i]))
    return np.mean(res, axis = 0)

def repeatP(l,b):
    p = np.random.randint(0,360,5)
    res = []
    for i in range(len(p)):
        res.append(stack_P(l,b,p[i]))
    return np.mean(res, axis = 0)

# %%
t0 = time()
glo = df['GLON']
gla = df['GLAT']
num_proc = 16
pool = multiprocessing.Pool(processes = num_proc)

process_I = [pool.apply_async(repeatI,
                               args = (i, j)) for i, j in zip(glo, gla)]
res_I = [p.get() for p in process_I]

process_P = [pool.apply_async(repeatP,
                               args = (i, j)) for i, j in zip(glo, gla)]
res_P = [p.get() for p in process_P]
pool.close()
pool.join()
print(f'Stacking complete in in {(time()-t0)/60}m')
stack = [res_I, res_P]

###------ Uncomment this if you want to save all patches ------###
#with open(output_dir + "full_sample_patches.pkl", 'wb') as f:
#    pickle.dump(stack, f)
# Out:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-23:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process ForkPoolWorker-8:
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7a582b165c04> in <module>
#      12 process_P = [pool.apply_async(repeatP,
#      13                                args = (i, j, p)) for i, j in zip(glo, gla)]
# ---> 14 res_P = [p.get() for p in process_P]
#      15 pool.close()
#      16 pool.join()
#
# <ipython-input-7-7a582b165c04> in <listcomp>(.0)
#      12 process_P = [pool.apply_async(repeatP,
#      13                                args = (i, j, p)) for i, j in zip(glo, gla)]
# ---> 14 res_P = [p.get() for p in process_P]
#      15 pool.close()
#      16 pool.join()
#
# ~/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/.conda/envs/jc_env/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/.conda/envs/jc_env/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Stack and observe results

# %%
with open('/global/cscratch1/sd/justinc/delete_me_output.pkl', 'rb') as f:
    stack = pickle.load(f)

# %%
stacked_sample = utils.sumstack(stack.copy())
background_corrected_sample = utils.BkgSubtract(stacked_sample.copy(), 18, 6)[0]

Polarisation_Fraction = (background_corrected_sample[1]/background_corrected_sample[0])[25][25]

# %%
plt.rcParams.update({'font.size': 24})
fig, axs = plt.subplots(2,2,figsize=(10,10),)
fig.subplots_adjust(left = 0.02, bottom = 0.06, right = 1.45, top = 0.94, wspace = 0.1, hspace = 0.08)
ims = [utils.sumstack(stack.copy())[0], utils.sumstack(stack.copy())[1], background_corrected_sample[0], background_corrected_sample[1]]
for i in range(len(axs.ravel())):
    im = axs.ravel()[i].imshow(ims[i], extent=[-ims[i].shape[1]/2., ims[i].shape[1]/2., -ims[i].shape[0]/2., ims[i].shape[0]/2. ])
    if i == 1 or i == 3:   
        fig.colorbar(im, ax=axs.ravel()[i],fraction=0.046*(ims[i].shape[0]/ims[i].shape[1]), 
                     pad=0.035, label = "$\mu$K$_{RJ}$")
    else:
        fig.colorbar(im, ax=axs.ravel()[i],fraction=0.046*(ims[i].shape[0]/ims[i].shape[1]), 
                     pad=0.035, label = "$\mu$K$_{RJ}$")
        
axs[0][0].axes.get_xaxis().set_visible(False)
axs[0][1].axes.get_xaxis().set_visible(False)
axs[0][0].set_title(r'$I^2$')
axs[0][1].set_title(r'$P^2$')
axs[1][1].set_xlabel("arcmin(')")
axs[1][0].set_xlabel("arcmin(')")
axs[0][0].set_ylabel("arcmin(')")
axs[1][0].set_ylabel("arcmin(')")
axs[1][1].set_ylabel("arcmin(')")
axs[0][1].set_ylabel("arcmin(')")
plt.savefig('IPcutouts_filtered_new.pdf',bbox_inches='tight')

# %% [markdown]
# # Bootstrap Stack for Error Calculation

# %%
t0 = time()
filtered_bootstraps = utils.bootstrap_stack(sample = stack.copy(), 
                                     sample_size = 2500,
                                     Bkg_Sub = True)
print(f'Bootstrap 2500 samples in {(time()-t0)/60}m')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-faf04846d59d> in <module>
#       2 filtered_bootstraps = utils.bootstrap_stack(sample = stack.copy(),
#       3                                      sample_size = 2500,
# ----> 4                                      Bkg_Sub = True)
#       5 print(f'Bootstrap 2500 samples in {(time()-t0)/60}m')
#
# /global/u1/j/justinc/PGCC_stacked_polarisation_fraction_analysis_code/utils.py in bootstrap_stack(sample, sample_size, Bkg_Sub)
#     100         bootstrap_I_samples = [src_rawI[i] for i in bootstrap_samples]
#     101         btstp = [bootstrap_I_samples, bootstrap_P_samples]
# --> 102         btstp_stacked = sumstack(btstp)
#     103
#     104         if Bkg_Sub == True:
#
# /global/u1/j/justinc/PGCC_stacked_polarisation_fraction_analysis_code/utils.py in sumstack(m)
#      27     mI, mP = m
#      28     SmI = np.sum(mI, axis = 0) / len(mI)
# ---> 29     SmP = np.sum(mP, axis = 0) / len(mP)
#      30     return [SmI, SmP]
#      31
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/.conda/envs/jc_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2246
#    2247     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2248                           initial=initial, where=where)
#    2249
#    2250
#
# ~/.conda/envs/jc_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %%
bootstrap_outputs = utils.bootstraps2error(filtered_bootstraps)
full_sample_squared_results = utils.final_results(bootstrap_outputs)
full_sample_sqrt_results = utils.sqrt_res(full_sample_squared_results)

# %%
print(full_sample_squared_results)
print(full_sample_sqrt_results)

# %% [markdown]
# # Break sample into flux density bins

# %%
n_bins = 7
bins = np.logspace(-0.65, 2.525, n_bins)
flux_bins = []
for i in range(n_bins-1):
    b = df['FLUX_353_CLUMP'][df['FLUX_353_CLUMP'].between(bins[i],bins[i+1])].index.tolist()
    flux_bins.append(df.loc[df.index[b]])
print([len(flux_bins[i]) for i in range(n_bins - 1)])
# Out:
# [99, 1565, 3141, 1298, 165, 16]

# %%
colours_bw = plt.cm.Paired(np.linspace(0,1,12))
CB_color_cycle = ['#E69F00', '#56B4E9', '#009E73',
                  '#F0E442', '#0072B2', '#D55E00',
                  '#CC79A7']

plt.rcParams.update({'font.size': 18})

fbin_labels2 = [
    r"[0,    0.64]", 
    r"[0.64, 1.8]",
    r"[1.8,  5.1]", 
    r"[5.1,  15]", 
    r"[15,   41]", 
    r"[41,   120]", 
    r"[120,  330]"]


plt.figure(figsize = (10,10))
for i in range(len(flux_bins)):
    plt.hist(flux_bins[i]['FLUX_353_CLUMP'], bins = 1, label = f'{fbin_labels2[i]}',
            color = colours_bw[i], histtype = 'stepfilled')
plt.legend()
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'Flux Density [$Jy$]')
plt.ylabel('N')
plt.tight_layout()
plt.savefig('fluxbins.pdf')
plt.show()

# %%
binned_stacks = []
for df_bin in flux_bins:
    t0 = time()
    glo = df_bin['GLON']
    gla = df_bin['GLAT']
    num_proc = 16
    pool = multiprocessing.Pool(processes = num_proc)
    process_I = [pool.apply_async(stack_I,
                                   args = (i, j)) for i, j in zip(glo, gla)]
    res_I = [p.get() for p in process_I]

    process_P = [pool.apply_async(stack_P,
                                   args = (i, j)) for i, j in zip(glo, gla)]
    res_P = [p.get() for p in process_P]
    pool.close()
    pool.join()
    print("Stacking complete in:", time()-t0)
    stack = [res_I, res_P]
    binned_stacks.append(stack)

###------ Uncomment this if you want to save all patches ------###
#with open("/global/cscratch1/sd/justinc/flux_binned_stacks.pkl", 'wb') as f:
#    pickle.dump(binned_stacks, f)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# TypeError: stack_I() missing 1 required positional argument: 'p'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f18c770019e6> in <module>
#       8     process_I = [pool.apply_async(stack_I,
#       9                                    args = (i, j)) for i, j in zip(glo, gla)]
# ---> 10     res_I = [p.get() for p in process_I]
#      11
#      12     process_P = [pool.apply_async(stack_P,
#
# <ipython-input-11-f18c770019e6> in <listcomp>(.0)
#       8     process_I = [pool.apply_async(stack_I,
#       9                                    args = (i, j)) for i, j in zip(glo, gla)]
# ---> 10     res_I = [p.get() for p in process_I]
#      11
#      12     process_P = [pool.apply_async(stack_P,
#
# ~/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# TypeError: stack_I() missing 1 required positional argument: 'p'
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Process ForkPoolWorker-3:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/global/homes/j/justinc/.conda/envs/jc_env/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt

# %%
with open('/global/cscratch1/sd/justinc/flux_8_binned_stacks.pkl', 'rb') as f:
    binned_stacks = pickle.load(f)

# %%
binned_bootstraps = []
binned_bootstraps_control = []
for i in binned_stacks:
    t0 = time()
    filtered_bootstraps = utils.bootstrap_stack(sample = i.copy(), 
                                     sample_size = 2500,
                                     Bkg_Sub = True)
    unfiltered_bootstraps = utils.bootstrap_stack(sample = i.copy(), 
                                     sample_size = 2500,
                                     Bkg_Sub = False)
    print(f'Bootstrap 2500 samples in {(time()-t0)/60}m')
    binned_bootstraps.append(filtered_bootstraps)
    binned_bootstraps_control.append(unfiltered_bootstraps)
# Out:
# Bootstrap 2500 samples in 0.06321266889572144m

# %%
binned_bootstrap_outputs = utils.bootstraps2error_bins(binned_bootstraps)
binned_bootstrap_control_outputs = utils.bootstraps2error_bins(binned_bootstraps_control)

# %%
full_sample_squared_results_binned = utils.final_results(binned_bootstrap_outputs)
mean_full_sample_squared_results_binned = utils.meanbinres(full_sample_squared_results_binned)
full_sample_sqrt_results_binned = utils.sqrt_res(full_sample_squared_results_binned)
mean_full_sample_sqrt_results_binned = utils.meanbinres(full_sample_sqrt_results_binned)

full_sample_squared_results_control_binned = utils.final_results(binned_bootstrap_control_outputs)
mean_full_sample_squared_results_control_binned = utils.meanbinres(full_sample_squared_results_control_binned)
full_sample_sqrt_results_control_binned = utils.sqrt_res(full_sample_squared_results_control_binned)
mean_full_sample_sqrt_results_control_binned = utils.meanbinres(full_sample_sqrt_results_control_binned)

# %%
fig, ax = plt.subplots(figsize = (17.5,8))

x              = np.logspace(-0.65, 2.525, n_bins+1)[1:-1]/2
control_points = full_sample_sqrt_results_control_binned[0]
control_err    = full_sample_sqrt_results_control_binned[2]
result_points  = full_sample_sqrt_results_binned[0]
result_err     = full_sample_sqrt_results_binned[2]

bin_mean       = mean_full_sample_sqrt_results_binned[1][0]
bin_err        = mean_full_sample_sqrt_results_binned[1][1]

plt.errorbar(np.log(x), 
             result_points, 
             yerr = result_err, 
             fmt = 'o', 
             color = 'red', 
             marker = 'o', 
             markersize = 10,
             capsize = 8, 
             fillstyle='full', lw = 5, label = 'Filtered')

plt.axhline(bin_mean, lw = 2, ls = '--', color = 'k')

ax.text(0.725, 0.15, r'$\sqrt{\langle\Pi^2\rangle} = %.4f \pm %.4f$' % 
        (bin_mean, bin_err), ha='left', va='bottom', 
        transform=ax.transAxes, fontsize = 20)
plt.ylabel(r'$\sqrt{\langle\Pi^2\rangle}$')
plt.xlabel(r'Flux Density [$\ln{(Jy)}$]')
plt.title(r'RMS Polarisation binned by flux density [$Jy$]')
plt.grid()
plt.ylim(0.,0.05)
#plt.legend()
#plt.savefig('binned_flux_density_new.pdf')
plt.show()
